# %% [markdown]
# **Data Analysis Final Project_ Bank Customer Analysis**

# %% [markdown]
# ***Project on Bank Customers Details comprising of customer information (e.g., Name, Customer ID), financial performance indicators (e.g., Credit Score, Balance), customer engagement metrics (e.g., Tenure, Number of Products, IsActiveMember) and Customer's status (exited the bank or Active)***

# %% [markdown]
# **Problem Statement**
#
#  -Analyze the dataset to gain insights into customer behavior
#
#  -Financial standing
#
#  -Engagement patterns.

# %% [raw]
# Read in your data(Customer_Info and Account_Info) from two different sheets and merge it to form a dataset.
# Also read in data dictionary of the dataset to be used for proper understanding of the columns.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Bank_Data_Set_Cust_Info=pd.read_csv('Bank_Churn_Messy.xlsx - Customer_Info.csv')

# %%
Bank_Data_Set_Cust_Info
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0        15634602   Hargrave          619       FRA  Female  42.0       2
# 1        15647311       Hill          608     Spain  Female  41.0       1
# 2        15619304       Onio          502    French  Female  42.0       8
# 3        15701354       Boni          699       FRA  Female  39.0       1
# 4        15737888   Mitchell          850     Spain  Female  43.0       2
# ...           ...        ...          ...       ...     ...   ...     ...
# 9996     15569892  Johnstone          516    French    Male  35.0      10
# 9997     15584532        Liu          709       FRA  Female  36.0       7
# 9998     15682355  Sabbatini          772   Germany    Male  42.0       3
# 9999     15628319     Walker          792    French  Female  28.0       4
# 10000    15628319     Walker          792    French  Female  28.0       4
#
#       EstimatedSalary
# 0          €101348.88
# 1          €112542.58
# 2          €113931.57
# 3           €93826.63
# 4            €79084.1
# ...               ...
# 9996       €101699.77
# 9997        €42085.58
# 9998        €92888.52
# 9999        €38190.78
# 10000       €38190.78
#
# [10001 rows x 8 columns]

# %%
Bank_Data_Set_Acc_Info=pd.read_csv('Bank_Churn_Messy.xlsx - Account_Info.csv')

# %%
Bank_Data_Set_Acc_Info
# Out:
#        CustomerId     Balance  NumOfProducts HasCrCard  Tenure IsActiveMember  \
# 0        15634602        €0.0              1       Yes       2            Yes
# 1        15634602        €0.0              1       Yes       2            Yes
# 2        15647311   €83807.86              1       Yes       1            Yes
# 3        15619304   €159660.8              3        No       8             No
# 4        15701354        €0.0              2        No       1             No
# ...           ...         ...            ...       ...     ...            ...
# 9997     15569892   €57369.61              1       Yes      10            Yes
# 9998     15584532        €0.0              1       Yes       7            Yes
# 9999     15682355   €75075.31              2        No       3             No
# 10000    15628319  €130142.79              1        No       4             No
# 10001    15628319  €130142.79              1        No       4             No
#
#        Exited
# 0           1
# 1           1
# 2           0
# 3           1
# 4           0
# ...       ...
# 9997        0
# 9998        1
# 9999        1
# 10000       0
# 10001       0
#
# [10002 rows x 7 columns]

# %%
comb_Bank_Cust_Data=pd.merge(Bank_Data_Set_Cust_Info,Bank_Data_Set_Acc_Info, on='CustomerId', how='left')

# %%
comb_Bank_Cust_Data
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure_x  \
# 0        15634602   Hargrave          619       FRA  Female  42.0         2
# 1        15634602   Hargrave          619       FRA  Female  42.0         2
# 2        15647311       Hill          608     Spain  Female  41.0         1
# 3        15619304       Onio          502    French  Female  42.0         8
# 4        15701354       Boni          699       FRA  Female  39.0         1
# ...           ...        ...          ...       ...     ...   ...       ...
# 9999     15682355  Sabbatini          772   Germany    Male  42.0         3
# 10000    15628319     Walker          792    French  Female  28.0         4
# 10001    15628319     Walker          792    French  Female  28.0         4
# 10002    15628319     Walker          792    French  Female  28.0         4
# 10003    15628319     Walker          792    French  Female  28.0         4
#
#       EstimatedSalary     Balance  NumOfProducts HasCrCard  Tenure_y  \
# 0          €101348.88        €0.0              1       Yes         2
# 1          €101348.88        €0.0              1       Yes         2
# 2          €112542.58   €83807.86              1       Yes         1
# 3          €113931.57   €159660.8              3        No         8
# 4           €93826.63        €0.0              2        No         1
# ...               ...         ...            ...       ...       ...
# 9999        €92888.52   €75075.31              2        No         3
# 10000       €38190.78  €130142.79              1        No         4
# 10001       €38190.78  €130142.79              1        No         4
# 10002       €38190.78  €130142.79              1        No         4
# 10003       €38190.78  €130142.79              1        No         4
#
#       IsActiveMember  Exited
# 0                Yes       1
# 1                Yes       1
# 2                Yes       0
# 3                 No       1
# 4                 No       0
# ...              ...     ...
# 9999              No       1
# 10000             No       0
# 10001             No       0
# 10002             No       0
# 10003             No       0
#
# [10004 rows x 14 columns]

# %%
comb_Bank_Cust_Data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure_x  \
# 0    15634602  Hargrave          619       FRA  Female  42.0         2
# 1    15634602  Hargrave          619       FRA  Female  42.0         2
# 2    15647311      Hill          608     Spain  Female  41.0         1
# 3    15619304      Onio          502    French  Female  42.0         8
# 4    15701354      Boni          699       FRA  Female  39.0         1
#
#   EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure_y  \
# 0      €101348.88       €0.0              1       Yes         2
# 1      €101348.88       €0.0              1       Yes         2
# 2      €112542.58  €83807.86              1       Yes         1
# 3      €113931.57  €159660.8              3        No         8
# 4       €93826.63       €0.0              2        No         1
#
#   IsActiveMember  Exited
# 0            Yes       1
# 1            Yes       1
# 2            Yes       0
# 3             No       1
# 4             No       0

# %%
comb_Bank_Cust_Data.tail()
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure_x  \
# 9999     15682355  Sabbatini          772   Germany    Male  42.0         3
# 10000    15628319     Walker          792    French  Female  28.0         4
# 10001    15628319     Walker          792    French  Female  28.0         4
# 10002    15628319     Walker          792    French  Female  28.0         4
# 10003    15628319     Walker          792    French  Female  28.0         4
#
#       EstimatedSalary     Balance  NumOfProducts HasCrCard  Tenure_y  \
# 9999        €92888.52   €75075.31              2        No         3
# 10000       €38190.78  €130142.79              1        No         4
# 10001       €38190.78  €130142.79              1        No         4
# 10002       €38190.78  €130142.79              1        No         4
# 10003       €38190.78  €130142.79              1        No         4
#
#       IsActiveMember  Exited
# 9999              No       1
# 10000             No       0
# 10001             No       0
# 10002             No       0
# 10003             No       0

# %%
Bank_data_dictionary=pd.read_csv('Bank_Churn_Data_Dictionary.csv')

# %%
Bank_data_dictionary
# Out:
#               Field                                        Description
# 0        CustomerId              A unique identifier for each customer
# 1           Surname                           The customer's last name
# 2       CreditScore  A numerical value representing the customer's ...
# 3         Geography  The country where the customer resides (France...
# 4            Gender             The customer's gender (Male or Female)
# 5               Age                                 The customer's age
# 6            Tenure  The number of years the customer has been with...
# 7           Balance                     The customer's account balance
# 8     NumOfProducts  The number of bank products the customer uses ...
# 9         HasCrCard  Whether the customer has a credit card (1 = ye...
# 10   IsActiveMember  Whether the customer is an active member (1 = ...
# 11  EstimatedSalary               The estimated salary of the customer
# 12           Exited  Whether the customer has churned (1 = yes, 0 =...

# %% [markdown]
# **Data Exploration**

# %%
comb_Bank_Cust_Data.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure_x', 'EstimatedSalary', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'Tenure_y', 'IsActiveMember', 'Exited'],
#       dtype='object')

# %%
comb_Bank_Cust_Data.shape
# Out:
# (10004, 14)

# %%
comb_Bank_Cust_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10004 entries, 0 to 10003
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10004 non-null  int64
#  1   Surname          10001 non-null  object
#  2   CreditScore      10004 non-null  int64
#  3   Geography        10004 non-null  object
#  4   Gender           10004 non-null  object
#  5   Age              10001 non-null  float64
#  6   Tenure_x         10004 non-null  int64
#  7   EstimatedSalary  10004 non-null  object
#  8   Balance          10004 non-null  object
#  9   NumOfProducts    10004 non-null  int64
#  10  HasCrCard        10004 non-null  object
#  11  Tenure_y         10004 non-null  int64
#  12  IsActiveMember   10004 non-null  object
#  13  Exited           10004 non-null  int64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 1.1+ MB

# %%
##For us to continue, it is advisable to create a copy of your dateset##

comb_Bank_Cust_Data_copy=comb_Bank_Cust_Data.copy()

# %%
comb_Bank_Cust_Data_copy
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure_x  \
# 0        15634602   Hargrave          619       FRA  Female  42.0         2
# 1        15634602   Hargrave          619       FRA  Female  42.0         2
# 2        15647311       Hill          608     Spain  Female  41.0         1
# 3        15619304       Onio          502    French  Female  42.0         8
# 4        15701354       Boni          699       FRA  Female  39.0         1
# ...           ...        ...          ...       ...     ...   ...       ...
# 9999     15682355  Sabbatini          772   Germany    Male  42.0         3
# 10000    15628319     Walker          792    French  Female  28.0         4
# 10001    15628319     Walker          792    French  Female  28.0         4
# 10002    15628319     Walker          792    French  Female  28.0         4
# 10003    15628319     Walker          792    French  Female  28.0         4
#
#       EstimatedSalary     Balance  NumOfProducts HasCrCard  Tenure_y  \
# 0          €101348.88        €0.0              1       Yes         2
# 1          €101348.88        €0.0              1       Yes         2
# 2          €112542.58   €83807.86              1       Yes         1
# 3          €113931.57   €159660.8              3        No         8
# 4           €93826.63        €0.0              2        No         1
# ...               ...         ...            ...       ...       ...
# 9999        €92888.52   €75075.31              2        No         3
# 10000       €38190.78  €130142.79              1        No         4
# 10001       €38190.78  €130142.79              1        No         4
# 10002       €38190.78  €130142.79              1        No         4
# 10003       €38190.78  €130142.79              1        No         4
#
#       IsActiveMember  Exited
# 0                Yes       1
# 1                Yes       1
# 2                Yes       0
# 3                 No       1
# 4                 No       0
# ...              ...     ...
# 9999              No       1
# 10000             No       0
# 10001             No       0
# 10002             No       0
# 10003             No       0
#
# [10004 rows x 14 columns]

# %% [raw]
# Data issue as seen from data information
# - Surname and Age has null 3 values each
# - Age, EstimatedSalary and Balance data type issue

# %% [markdown]
# Removing the Euro sign in EstimatedSalary and Balance column so i can change data type

# %%
comb_Bank_Cust_Data['EstimatedSalary']=comb_Bank_Cust_Data['EstimatedSalary'].str.replace('€','')

# %%
comb_Bank_Cust_Data['Balance']=comb_Bank_Cust_Data['Balance'].str.replace('€','')

# %%
comb_Bank_Cust_Data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure_x  \
# 0    15634602  Hargrave          619       FRA  Female  42.0         2
# 1    15634602  Hargrave          619       FRA  Female  42.0         2
# 2    15647311      Hill          608     Spain  Female  41.0         1
# 3    15619304      Onio          502    French  Female  42.0         8
# 4    15701354      Boni          699       FRA  Female  39.0         1
#
#   EstimatedSalary   Balance  NumOfProducts HasCrCard  Tenure_y IsActiveMember  \
# 0       101348.88       0.0              1       Yes         2            Yes
# 1       101348.88       0.0              1       Yes         2            Yes
# 2       112542.58  83807.86              1       Yes         1            Yes
# 3       113931.57  159660.8              3        No         8             No
# 4        93826.63       0.0              2        No         1             No
#
#    Exited
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0

# %%
comb_Bank_Cust_Data.tail()
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure_x  \
# 9999     15682355  Sabbatini          772   Germany    Male  42.0         3
# 10000    15628319     Walker          792    French  Female  28.0         4
# 10001    15628319     Walker          792    French  Female  28.0         4
# 10002    15628319     Walker          792    French  Female  28.0         4
# 10003    15628319     Walker          792    French  Female  28.0         4
#
#       EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure_y  \
# 9999         92888.52   75075.31              2        No         3
# 10000        38190.78  130142.79              1        No         4
# 10001        38190.78  130142.79              1        No         4
# 10002        38190.78  130142.79              1        No         4
# 10003        38190.78  130142.79              1        No         4
#
#       IsActiveMember  Exited
# 9999              No       1
# 10000             No       0
# 10001             No       0
# 10002             No       0
# 10003             No       0

# %%
comb_Bank_Cust_Data.isnull().sum()
# Out:
# CustomerId         0
# Surname            3
# CreditScore        0
# Geography          0
# Gender             0
# Age                3
# Tenure_x           0
# EstimatedSalary    0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# Tenure_y           0
# IsActiveMember     0
# Exited             0
# dtype: int64

# %%
comb_Bank_Cust_Data.isnull().sum()/len(comb_Bank_Cust_Data)*100
# Out:
# CustomerId         0.000000
# Surname            0.029988
# CreditScore        0.000000
# Geography          0.000000
# Gender             0.000000
# Age                0.029988
# Tenure_x           0.000000
# EstimatedSalary    0.000000
# Balance            0.000000
# NumOfProducts      0.000000
# HasCrCard          0.000000
# Tenure_y           0.000000
# IsActiveMember     0.000000
# Exited             0.000000
# dtype: float64

# %%
comb_Bank_Cust_Data[comb_Bank_Cust_Data['Surname'].isnull()]
# Out:
#       CustomerId Surname  CreditScore Geography  Gender  Age  Tenure_x  \
# 29      15728693     NaN          574   Germany  Female  NaN         3
# 122     15580203     NaN          674     Spain    Male  NaN         6
# 9390    15756954     NaN          538    France  Female  NaN         2
#
#      EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure_y  \
# 29           -999999  141349.43              1       Yes         3
# 122          -999999  120193.42              1        No         6
# 9390         -999999        0.0              1       Yes         2
#
#      IsActiveMember  Exited
# 29              Yes       0
# 122              No       0
# 9390            Yes       0

# %%
comb_Bank_Cust_Data[comb_Bank_Cust_Data['Age'].isnull()]
# Out:
#       CustomerId Surname  CreditScore Geography  Gender  Age  Tenure_x  \
# 29      15728693     NaN          574   Germany  Female  NaN         3
# 122     15580203     NaN          674     Spain    Male  NaN         6
# 9390    15756954     NaN          538    France  Female  NaN         2
#
#      EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure_y  \
# 29           -999999  141349.43              1       Yes         3
# 122          -999999  120193.42              1        No         6
# 9390         -999999        0.0              1       Yes         2
#
#      IsActiveMember  Exited
# 29              Yes       0
# 122              No       0
# 9390            Yes       0

# %%
comb_Bank_Cust_Data.dropna(axis=0,inplace=True)

# %%
comb_Bank_Cust_Data.duplicated().sum()
# Out:
# 4

# %%
comb_Bank_Cust_Data_duplicates=comb_Bank_Cust_Data[comb_Bank_Cust_Data.duplicated('CustomerId')]

# %%
comb_Bank_Cust_Data_duplicates
# Out:
#        CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure_x  \
# 1        15634602  Hargrave          619       FRA  Female  42.0         2
# 10001    15628319    Walker          792    French  Female  28.0         4
# 10002    15628319    Walker          792    French  Female  28.0         4
# 10003    15628319    Walker          792    French  Female  28.0         4
#
#       EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure_y  \
# 1           101348.88        0.0              1       Yes         2
# 10001        38190.78  130142.79              1        No         4
# 10002        38190.78  130142.79              1        No         4
# 10003        38190.78  130142.79              1        No         4
#
#       IsActiveMember  Exited
# 1                Yes       1
# 10001             No       0
# 10002             No       0
# 10003             No       0

# %%
comb_Bank_Cust_Data_drop_duplicates=comb_Bank_Cust_Data.drop_duplicates()

# %%
comb_Bank_Cust_Data_drop_duplicates
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure_x  \
# 0        15634602   Hargrave          619       FRA  Female  42.0         2
# 2        15647311       Hill          608     Spain  Female  41.0         1
# 3        15619304       Onio          502    French  Female  42.0         8
# 4        15701354       Boni          699       FRA  Female  39.0         1
# 5        15737888   Mitchell          850     Spain  Female  43.0         2
# ...           ...        ...          ...       ...     ...   ...       ...
# 9996     15606229   Obijiaku          771    France    Male  39.0         5
# 9997     15569892  Johnstone          516    French    Male  35.0        10
# 9998     15584532        Liu          709       FRA  Female  36.0         7
# 9999     15682355  Sabbatini          772   Germany    Male  42.0         3
# 10000    15628319     Walker          792    French  Female  28.0         4
#
#       EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure_y  \
# 0           101348.88        0.0              1       Yes         2
# 2           112542.58   83807.86              1       Yes         1
# 3           113931.57   159660.8              3        No         8
# 4            93826.63        0.0              2        No         1
# 5             79084.1  125510.82              1       Yes         2
# ...               ...        ...            ...       ...       ...
# 9996         96270.64        0.0              2        No         5
# 9997        101699.77   57369.61              1       Yes        10
# 9998         42085.58        0.0              1       Yes         7
# 9999         92888.52   75075.31              2        No         3
# 10000        38190.78  130142.79              1        No         4
#
#       IsActiveMember  Exited
# 0                Yes       1
# 2                Yes       0
# 3                 No       1
# 4                 No       0
# 5                Yes       0
# ...              ...     ...
# 9996              No       0
# 9997             Yes       0
# 9998             Yes       1
# 9999              No       1
# 10000             No       0
#
# [9997 rows x 14 columns]

# %%
comb_Bank_Cust_Data.duplicated().value_counts()
# Out:
# False    9997
# True        4
# Name: count, dtype: int64

# %%
comb_Bank_Cust_Data_drop.duplicated().sum()
# Out:
# 0

# %%
comb_Bank_Cust_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10001 entries, 0 to 10003
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10001 non-null  int64
#  1   Surname          10001 non-null  object
#  2   CreditScore      10001 non-null  int64
#  3   Geography        10001 non-null  object
#  4   Gender           10001 non-null  object
#  5   Age              10001 non-null  float64
#  6   Tenure_x         10001 non-null  int64
#  7   EstimatedSalary  10001 non-null  object
#  8   Balance          10001 non-null  object
#  9   NumOfProducts    10001 non-null  int64
#  10  HasCrCard        10001 non-null  object
#  11  Tenure_y         10001 non-null  int64
#  12  IsActiveMember   10001 non-null  object
#  13  Exited           10001 non-null  int64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 1.1+ MB

# %%
comb_Bank_Cust_Data[comb_Bank_Cust_Data['Age'].isnull()]
# Out:
#      CustomerId Surname  CreditScore Geography Gender  Age  Tenure_x  \
# Age         NaN     NaN          NaN       NaN    NaN  NaN       NaN
#
#     EstimatedSalary Balance  NumOfProducts HasCrCard  Tenure_y IsActiveMember  \
# Age             NaN     NaN            NaN       NaN       NaN            NaN
#
#      Exited
# Age     NaN

# %%
comb_Bank_Cust_Data['Age'].isnull().sum()
# Out:
# 1

# %%
comb_Bank_Cust_Data.drop('Age', axis=0, inplace=True)

# %%
comb_Bank_Cust_Data['Age'].isnull().sum()
# Out:
# 0

# %%
comb_Bank_Cust_Data['Age'] = comb_Bank_Cust_Data['Age'].astype('int64')

# %%
comb_Bank_Cust_Data['Exited'] = comb_Bank_Cust_Data['Exited'].astype('int64')

# %%
comb_Bank_Cust_Data['EstimatedSalary']=comb_Bank_Cust_Data['EstimatedSalary'].astype('float64')

# %%
comb_Bank_Cust_Data['Balance']=comb_Bank_Cust_Data['Balance'].astype('float64')

# %%
comb_Bank_Cust_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10001 entries, 0 to 10003
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10001 non-null  float64
#  1   Surname          10001 non-null  object
#  2   CreditScore      10001 non-null  float64
#  3   Geography        10001 non-null  object
#  4   Gender           10001 non-null  object
#  5   Age              10001 non-null  int64
#  6   Tenure_x         10001 non-null  float64
#  7   EstimatedSalary  10001 non-null  float64
#  8   Balance          10001 non-null  float64
#  9   NumOfProducts    10001 non-null  float64
#  10  HasCrCard        10001 non-null  object
#  11  Tenure_y         10001 non-null  float64
#  12  IsActiveMember   10001 non-null  object
#  13  Exited           10001 non-null  int64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
comb_Bank_Cust_Data['Geography'].replace({'FRA':'France'})
# Out:
# 0         France
# 1         France
# 2          Spain
# 3         French
# 4         France
#           ...
# 9999     Germany
# 10000     French
# 10001     French
# 10002     French
# 10003     French
# Name: Geography, Length: 10001, dtype: object

# %%
comb_Bank_Cust_Data.describe()
# Out:
#          CustomerId   CreditScore           Age      Tenure_x  \
# count  1.000100e+04  10001.000000  10001.000000  10001.000000
# mean   1.569092e+07    650.584642     38.919108      5.012599
# std    7.193043e+04     96.670158     10.488725      2.891996
# min    1.556570e+07    350.000000     18.000000      0.000000
# 25%    1.562842e+07    584.000000     32.000000      3.000000
# 50%    1.569070e+07    652.000000     37.000000      5.000000
# 75%    1.575322e+07    718.000000     44.000000      7.000000
# max    1.581569e+07    850.000000     92.000000     10.000000
#
#        EstimatedSalary        Balance  NumOfProducts      Tenure_y  \
# count     10001.000000   10001.000000   10001.000000  10001.000000
# mean     100073.779733   76491.128727       1.530147      5.012599
# std       57517.263050   62396.304066       0.581649      2.891996
# min          11.580000       0.000000       1.000000      0.000000
# 25%       50911.410000       0.000000       1.000000      3.000000
# 50%      100200.400000   97208.460000       1.000000      5.000000
# 75%      149384.430000  127655.220000       2.000000      7.000000
# max      199992.480000  250898.090000       4.000000     10.000000
#
#              Exited
# count  10001.000000
# mean       0.203780
# std        0.402827
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
comb_Bank_Cust_Data
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure_x  \
# 0      15634602.0   Hargrave        619.0    France  Female   42       2.0
# 1      15634602.0   Hargrave        619.0    France  Female   42       2.0
# 2      15647311.0       Hill        608.0     Spain  Female   41       1.0
# 3      15619304.0       Onio        502.0    French  Female   42       8.0
# 4      15701354.0       Boni        699.0    France  Female   39       1.0
# ...           ...        ...          ...       ...     ...  ...       ...
# 9999   15682355.0  Sabbatini        772.0   Germany    Male   42       3.0
# 10000  15628319.0     Walker        792.0    French  Female   28       4.0
# 10001  15628319.0     Walker        792.0    French  Female   28       4.0
# 10002  15628319.0     Walker        792.0    French  Female   28       4.0
# 10003  15628319.0     Walker        792.0    French  Female   28       4.0
#
#        EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure_y  \
# 0            101348.88       0.00            1.0       Yes       2.0
# 1            101348.88       0.00            1.0       Yes       2.0
# 2            112542.58   83807.86            1.0       Yes       1.0
# 3            113931.57  159660.80            3.0        No       8.0
# 4             93826.63       0.00            2.0        No       1.0
# ...                ...        ...            ...       ...       ...
# 9999          92888.52   75075.31            2.0        No       3.0
# 10000         38190.78  130142.79            1.0        No       4.0
# 10001         38190.78  130142.79            1.0        No       4.0
# 10002         38190.78  130142.79            1.0        No       4.0
# 10003         38190.78  130142.79            1.0        No       4.0
#
#       IsActiveMember  Exited
# 0                Yes       1
# 1                Yes       1
# 2                Yes       0
# 3                 No       1
# 4                 No       0
# ...              ...     ...
# 9999              No       1
# 10000             No       0
# 10001             No       0
# 10002             No       0
# 10003             No       0
#
# [10001 rows x 14 columns]

# %%
comb_Bank_Cust_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10001 entries, 0 to 10003
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10001 non-null  float64
#  1   Surname          10001 non-null  object
#  2   CreditScore      10001 non-null  float64
#  3   Geography        10001 non-null  object
#  4   Gender           10001 non-null  object
#  5   Age              10001 non-null  int64
#  6   Tenure_x         10001 non-null  float64
#  7   EstimatedSalary  10001 non-null  float64
#  8   Balance          10001 non-null  float64
#  9   NumOfProducts    10001 non-null  float64
#  10  HasCrCard        10001 non-null  object
#  11  Tenure_y         10001 non-null  float64
#  12  IsActiveMember   10001 non-null  object
#  13  Exited           10001 non-null  int64
# dtypes: float64(7), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
comb_Bank_Cust_Data
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure_x  \
# 0      15634602.0   Hargrave        619.0    France  Female   42       2.0
# 1      15634602.0   Hargrave        619.0    France  Female   42       2.0
# 2      15647311.0       Hill        608.0     Spain  Female   41       1.0
# 3      15619304.0       Onio        502.0    French  Female   42       8.0
# 4      15701354.0       Boni        699.0    France  Female   39       1.0
# ...           ...        ...          ...       ...     ...  ...       ...
# 9999   15682355.0  Sabbatini        772.0   Germany    Male   42       3.0
# 10000  15628319.0     Walker        792.0    French  Female   28       4.0
# 10001  15628319.0     Walker        792.0    French  Female   28       4.0
# 10002  15628319.0     Walker        792.0    French  Female   28       4.0
# 10003  15628319.0     Walker        792.0    French  Female   28       4.0
#
#        EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure_y  \
# 0            101348.88       0.00            1.0       Yes       2.0
# 1            101348.88       0.00            1.0       Yes       2.0
# 2            112542.58   83807.86            1.0       Yes       1.0
# 3            113931.57  159660.80            3.0        No       8.0
# 4             93826.63       0.00            2.0        No       1.0
# ...                ...        ...            ...       ...       ...
# 9999          92888.52   75075.31            2.0        No       3.0
# 10000         38190.78  130142.79            1.0        No       4.0
# 10001         38190.78  130142.79            1.0        No       4.0
# 10002         38190.78  130142.79            1.0        No       4.0
# 10003         38190.78  130142.79            1.0        No       4.0
#
#       IsActiveMember  Exited
# 0                Yes       1
# 1                Yes       1
# 2                Yes       0
# 3                 No       1
# 4                 No       0
# ...              ...     ...
# 9999              No       1
# 10000             No       0
# 10001             No       0
# 10002             No       0
# 10003             No       0
#
# [10001 rows x 14 columns]

# %%
comb_Bank_Cust_Data['CustomerId'] = comb_Bank_Cust_Data['CustomerId'].astype('int64')

# %%
comb_Bank_Cust_Data
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure_x  \
# 0        15634602   Hargrave        619.0    France  Female   42       2.0
# 1        15634602   Hargrave        619.0    France  Female   42       2.0
# 2        15647311       Hill        608.0     Spain  Female   41       1.0
# 3        15619304       Onio        502.0    French  Female   42       8.0
# 4        15701354       Boni        699.0    France  Female   39       1.0
# ...           ...        ...          ...       ...     ...  ...       ...
# 9999     15682355  Sabbatini        772.0   Germany    Male   42       3.0
# 10000    15628319     Walker        792.0    French  Female   28       4.0
# 10001    15628319     Walker        792.0    French  Female   28       4.0
# 10002    15628319     Walker        792.0    French  Female   28       4.0
# 10003    15628319     Walker        792.0    French  Female   28       4.0
#
#        EstimatedSalary    Balance  NumOfProducts HasCrCard  Tenure_y  \
# 0            101348.88       0.00            1.0       Yes       2.0
# 1            101348.88       0.00            1.0       Yes       2.0
# 2            112542.58   83807.86            1.0       Yes       1.0
# 3            113931.57  159660.80            3.0        No       8.0
# 4             93826.63       0.00            2.0        No       1.0
# ...                ...        ...            ...       ...       ...
# 9999          92888.52   75075.31            2.0        No       3.0
# 10000         38190.78  130142.79            1.0        No       4.0
# 10001         38190.78  130142.79            1.0        No       4.0
# 10002         38190.78  130142.79            1.0        No       4.0
# 10003         38190.78  130142.79            1.0        No       4.0
#
#       IsActiveMember  Exited
# 0                Yes       1
# 1                Yes       1
# 2                Yes       0
# 3                 No       1
# 4                 No       0
# ...              ...     ...
# 9999              No       1
# 10000             No       0
# 10001             No       0
# 10002             No       0
# 10003             No       0
#
# [10001 rows x 14 columns]

# %%
comb_Bank_Cust_Data.to_csv('Cleaned Data.csv')

# %%
comb_Bank_Cust_Data.to_excel('Cleaned Data.xlsx')

# %% [markdown]
# ***Data Analysis***
#
# # 1. Distribution of customers based on geography

# %%
Geography_counts = comb_Bank_Cust_Data['Geography'].value_counts()

# %%
Geography_counts
# Out:
# Geography
# France     3359
# Germany    2508
# Spain      2476
# French     1658
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=comb_Bank_Cust_Data, x='Geography', palette='viridis')
plt.title("Customer Distribution by Geography")
plt.xlabel("Geography")
plt.ylabel("Number of Customers")
plt.show()
# Out:
# C:\Users\Janny Fredericks\AppData\Local\Temp\ipykernel_1992\387101714.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=comb_Bank_Cust_Data, x='Geography', palette='viridis')
